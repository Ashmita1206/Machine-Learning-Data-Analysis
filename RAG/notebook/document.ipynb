# %% [markdown]
# DATA INGESTION

# %%
### dacoument datastructure 

from langchain_core.documents import Document

# %%
doc=Document{
    page_content="This is the main text content i am using to create RAG.",
    metadata={"source": "example.txt", "author": "ashmita", "date": "2024-06-01"}

}
